# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:02:44.410Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8144, 'name': 'tdjgif6l2ul', 'symbol': 'l1i9sbsrvdq', 'slug': 'tck5py7w1pq', 'cmc_rank': 1432, 'num_market_pairs': 1140, 'circulating_supply': 7254, 'total_supply': 7712, 'max_supply': 7982, 'infinite_supply': None, 'last_updated': '2024-02-20T06:02:44.410Z', 'date_added': '2024-02-20T06:02:44.410Z', 'tags': ['9oifw2y4kk', '2w6xtn7dhqy', '1z4f8hummxq', '9edtw7lllv6', 'yh9qqujfrf8', 'k287y2m8kf', 'bwqsjlniuhn', 'i2vcy1mtjf', 'j51lxwpem39', '1p8cphs860dj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9421768734194527, 'volume_24h': 4041, 'volume_change_24h': 0.2552277851221254, 'percent_change_1h': 0.20909536799669382, 'percent_change_24h': 0.018465690510858446, 'percent_change_7d': 0.9153567382193579, 'market_cap': 0.9528689519533211, 'market_cap_domi
# ...

# %%
print(data['data'])
# Out:
# [{'id': 8144, 'name': 'tdjgif6l2ul', 'symbol': 'l1i9sbsrvdq', 'slug': 'tck5py7w1pq', 'cmc_rank': 1432, 'num_market_pairs': 1140, 'circulating_supply': 7254, 'total_supply': 7712, 'max_supply': 7982, 'infinite_supply': None, 'last_updated': '2024-02-20T06:02:44.410Z', 'date_added': '2024-02-20T06:02:44.410Z', 'tags': ['9oifw2y4kk', '2w6xtn7dhqy', '1z4f8hummxq', '9edtw7lllv6', 'yh9qqujfrf8', 'k287y2m8kf', 'bwqsjlniuhn', 'i2vcy1mtjf', 'j51lxwpem39', '1p8cphs860dj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9421768734194527, 'volume_24h': 4041, 'volume_change_24h': 0.2552277851221254, 'percent_change_1h': 0.20909536799669382, 'percent_change_24h': 0.018465690510858446, 'percent_change_7d': 0.9153567382193579, 'market_cap': 0.9528689519533211, 'market_cap_dominance': 4389, 'fully_diluted_market_cap': 0.6836935489895626, 'last_updated': '2024-02-20T06:02:44.410Z'}}}, {'id': 4814, 'name': 'k935xbgrszo', 'symbo
# ...

# %%
import pandas as pd

# %%
print(data['data'])
# Out:
# [{'id': 8144, 'name': 'tdjgif6l2ul', 'symbol': 'l1i9sbsrvdq', 'slug': 'tck5py7w1pq', 'cmc_rank': 1432, 'num_market_pairs': 1140, 'circulating_supply': 7254, 'total_supply': 7712, 'max_supply': 7982, 'infinite_supply': None, 'last_updated': '2024-02-20T06:02:44.410Z', 'date_added': '2024-02-20T06:02:44.410Z', 'tags': ['9oifw2y4kk', '2w6xtn7dhqy', '1z4f8hummxq', '9edtw7lllv6', 'yh9qqujfrf8', 'k287y2m8kf', 'bwqsjlniuhn', 'i2vcy1mtjf', 'j51lxwpem39', '1p8cphs860dj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9421768734194527, 'volume_24h': 4041, 'volume_change_24h': 0.2552277851221254, 'percent_change_1h': 0.20909536799669382, 'percent_change_24h': 0.018465690510858446, 'percent_change_7d': 0.9153567382193579, 'market_cap': 0.9528689519533211, 'market_cap_dominance': 4389, 'fully_diluted_market_cap': 0.6836935489895626, 'last_updated': '2024-02-20T06:02:44.410Z'}}}, {'id': 4814, 'name': 'k935xbgrszo', 'symbo
# ...

# %%
df=pd.json_normalize(data['data'])

# %%
print(df)
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  8144  tdjgif6l2ul  l1i9sbsrvdq  tck5py7w1pq      1432              1140
# 1  4814  k935xbgrszo  67vlej9m8n7  n1xqrn24thk      8481               418
# 2  6935   i95zjlsi0n   vy6blxzwcm  2xbh1ffkgxg      7794               850
# 3  4743  bmrikotal5b   kvabq699er  obzf4uooicc      9600              8550
# 4  4698  krv510r4o88  dc6dmonx4bd   8tyfctj2ev      4257              9503
# 5   514   fomnlp0vaz  2i4ftqgcqf8    k79u9jlby      6963              2511
# 6  1140  zxyvqzyae8p  htyupe306yu   q2jdqcstys      3919              3695
# 7  8461  cdp4bg82daf  c5w5g5h2kjd   g2zlmdi3ss      2248              4852
# 8  1446   k0bddzubfq  xhgtbi72oyo  2mb7jpgu5jv      5044              6031
# 9   414  xmmzggrf0sh   gmrlcl0ooi  htilpcvzjzt      5215                 4
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                7254          7712        7982            None  ...
# ...

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'dba4504e-635c-4ef4-9746-f17a1b9ea92c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(data['data'])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df=pd.json_normalize(data['data'])

# %%
print(df)
# Out:
#          id                name symbol                slug  num_market_pairs  \
# 0         1             Bitcoin    BTC             bitcoin             10821
# 1      1027            Ethereum    ETH            ethereum              8428
# 2       825         Tether USDt   USDT              tether             74897
# 3      1839                 BNB    BNB                 bnb              2070
# 4      5426              Solana    SOL              solana               626
# ...     ...                 ...    ...                 ...               ...
# 4995  25299            Gays Inu  LGBTQ            gays-inu                 4
# 4996  27134  Doge on Pulsechain   DOGE  doge-on-pulsechain                 7
# 4997   9900                HODL   HODL                hodl                10
# 4998  11492         TCGCoin 2.0   TCG2         tcgcoin-2-0                13
# 4999  28644             ChainEx    CEX             chainex                 1
#
#                     date_added  \
# ...

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=375605b811ab92b5367c20ab01139035'  #actual url
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '375605b811ab92b5367c20ab01139035',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'coord': {'lon': 10.99, 'lat': 44.34}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 275.63, 'feels_like': 275.63, 'temp_min': 274.56, 'temp_max': 277.83, 'pressure': 1025, 'humidity': 78, 'sea_level': 1025, 'grnd_level': 936}, 'visibility': 10000, 'wind': {'speed': 1.27, 'deg': 334, 'gust': 1.28}, 'clouds': {'all': 100}, 'dt': 1708412854, 'sys': {'type': 2, 'id': 2011351, 'country': 'IT', 'sunrise': 1708409372, 'sunset': 1708447829}, 'timezone': 3600, 'id': 3163858, 'name': 'Zocca', 'cod': 200}

# %%
print(data['weather'])
# Out:
# [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]

# %%
df=pd.json_normalize(data['weather'])

# %%
print(df)
# Out:
#     id    main      description icon
# 0  804  Clouds  overcast clouds  04d
